# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/9. Sales-Data-Analysis.csv')

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df.sample(10)
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 79      10536  24-11-2022  Chicken Sandwiches   9.95    201.01   Drive-thru
# 88      10548  26-11-2022           Beverages   2.95    745.76   Drive-thru
# 150     10610  09-12-2022             Burgers  12.99    569.67       Online
# 130     10590  05-12-2022             Burgers  12.99    554.27       Online
# 171     10631  13-12-2022  Chicken Sandwiches   9.95    201.01       Online
# 214     10674  21-12-2022       Sides & Other   4.99    200.40     In-store
# 216     10676  22-12-2022  Chicken Sandwiches   9.95    241.21     In-store
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 207     10667  20-12-2022               Fries   3.49    630.37     In-store
# 172     10632  13-12-2022               Fries   3.49    630.37       Online
#
#     Payment Method        Manager    City
# 79     Credit Card    Pablo Perez  Madrid
# 88     Credit Card    Tom Jackson  London
# 150      Gift Card    Tom Jackson  London
# 130    Credit Card    Tom Jackson  London
# 171      Gift Card     Joao Silva  Lisbon
# 214           Cash     Joao Silva  Lisbon
# 216           Cash     Joao Silva  Lisbon
# 250      Gift Card  Walter Muller  Berlin
# 207           Cash     Joao Silva  Lisbon
# 172      Gift Card     Joao Silva  Lisbon

# %%
sns.countplot(df['Manager'])
df['Manager'].value_counts()
# Out:
# Manager
# Tom Jackson           74
# Joao Silva            70
# Pablo Perez           36
# Walter Muller         30
# Remy Monet            24
#        Pablo Perez     7
# Joao    Silva          5
#        Remy Monet      2
# Remy    Monet          1
# Tom      Jackson       1
# Pablo   Perez          1
# Remy     Monet         1
# Pablo    Perez         1
# Pablo  Perez           1
# Name: count, dtype: int64

# %%
df['Product'].value_counts()
# Out:
# Product
# Chicken Sandwiches    52
# Burgers               52
# Fries                 51
# Beverages             50
# Sides & Other         49
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# London    75
# Lisbon    75
# Madrid    46
# Berlin    30
# Paris     28
# Name: count, dtype: int64

# %%
df['Purchase Type'].value_counts()
# Out:
# Purchase Type
# Online         107
# In-store        86
# Drive-thru      61
# Name: count, dtype: int64

# %%
df['Price'].skew()
# Out:
# np.float64(1.0801318098822328)

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.histplot(df['Price'], kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>
